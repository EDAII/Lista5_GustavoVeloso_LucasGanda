# %%
from avl_tree import AVLTree, Node
from redblack_tree import RedBlackTree, Node

import time
import numpy as np
import pandas as pd
import random
from random import randint
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ### Funções utilizadas

# %%
def operation(arr, func):
    timespent = []
    for values in arr:
        t0 = time.time()
        for value in values:
            func(value)
        t1 = time.time()
        timespent.append(t1 - t0)
    
    return timespent

def get_timespent_array(arr, AVLfunc, RBfunc):
    timespent = [[], []]

    for i in range(1,20):
        timespent[0] = operation(arr, AVLfunc)
        timespent[1] = operation(arr, RBfunc)

    return timespent


def plot(xAxis, yAxisArray, title, operacao):
    plt.plot(xAxis, np.array(yAxisArray[0]), label="AVL Tree", color="blue")
    plt.plot(xAxis, np.array(yAxisArray[1]), label="Red-Black Tree", color="red")

    plt.legend(loc='upper left')
    plt.ylabel('Tempo Gasto',fontsize=15)
    plt.xlabel('Número de ' + operacao,fontsize=15)
    plt.title(title,fontsize=15)
    plt.show()
    
def vector_unsorted(vector_len):
    vector_desorganized =[]
    for each in range(vector_len):
        vector_desorganized.append(randint(0,999))
    return vector_desorganized

def timespent_generate_tree(tree, tree_size):
    inlist = vector_unsorted(tree_size)
    t0 = time.time()
    for i in inlist:
        tree.add(i)
    t1 = time.time()
    
    return t1 - t0

# %% [markdown]
# ## Tempo de criação, inserção e remoção em pequenas árvores

# %%
rb_tree = RedBlackTree()
avl_tree = AVLTree()

avl_timespent = timespent_generate_tree(avl_tree, 100)
rb_timespent = timespent_generate_tree(rb_tree, 100)

print(f'Tempo para montagem de uma Árvore AVL: {avl_timespent}')
print(f'Tempo para montagem de uma Árvore Vermelho e Preto: {rb_timespent}')
# Out:
# Tempo para montagem de uma Árvore AVL: 0.0029349327087402344
# Tempo para montagem de uma Árvore Vermelho e Preto: 0.000621795654296875

# %%
xAxis = [1,2,3]

timespent_to_insert = get_timespent_array([[110], [190, 130], [170, 220, 140]], avl_tree.add, rb_tree.add)
plot(xAxis, timespent_to_insert, 'Adição', 'adições')

timespent_to_remove = get_timespent_array([[5], [7, 2], [6, 3, 4]], avl_tree.delete, rb_tree.delete)
plot(xAxis, timespent_to_remove, 'Remoção', 'remoções')

# %% [markdown]
# ## Tempo de criação, inserção e remoção em grandes árvores

# %%
rb_tree = RedBlackTree()
avl_tree = AVLTree()

avl_timespent = timespent_generate_tree(avl_tree, 100000)
rb_timespent = timespent_generate_tree(rb_tree, 100000)

print(f'Tempo para montagem de uma Árvore AVL: {avl_timespent}')
print(f'Tempo para montagem de uma Árvore Vermelho e Preto: {rb_timespent}')
# Out:
# Tempo para montagem de uma Árvore AVL: 1.7177529335021973
# Tempo para montagem de uma Árvore Vermelho e Preto: 0.3268699645996094

# %%
xAxis = [3,6,9]

timespent_to_remove = get_timespent_array([[50, 150, 60000], [700, 20, 30000, 605, 78099, 12113], [3, 86540, 765, 1023, 10765, 54, 712, 999, 70]], avl_tree.delete, rb_tree.delete)
plot(xAxis, timespent_to_remove, 'Remoção', 'remoções')

timespent_to_insert = get_timespent_array([[50, 150, 60000], [700, 20, 30000, 605, 78099, 12113], [3, 86540, 765, 1023, 10765, 54, 712, 999, 70]], avl_tree.add, rb_tree.add)
plot(xAxis, timespent_to_insert, 'Adição', 'adições')

# %% [markdown]
# ## Busca de valor

# %%
rb_tree = RedBlackTree()
avl_tree = AVLTree()

avl_timespent = timespent_generate_tree(avl_tree, 100000)
rb_timespent = timespent_generate_tree(rb_tree, 100000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8ead7b2649a7> in <module>
#       2 avl_tree = AVLTree()
#       3
# ----> 4 avl_timespent = timespent_generate_tree(avl_tree, 100000)
#       5 rb_timespent = timespent_generate_tree(rb_tree, 100000)
#
# NameError: name 'timespent_generate_tree' is not defined

# %%
avl_tree.contains(555)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-76c708d186e7> in <module>
# ----> 1 avl_tree.contains(555)
#
# ~/Documents/UNB/EDA2/trabsons/Lista5_GustavoVeloso_LucasGanda/avl_tree.py in contains(self, value)
#      56
#      57     def contains(self, value) -> bool:
# ---> 58         return bool(self.find_node(value))
#      59
#      60     def find_node(self, key):
#
# ~/Documents/UNB/EDA2/trabsons/Lista5_GustavoVeloso_LucasGanda/avl_tree.py in find_node(self, value)
#      70
#      71     def rebalance(self):
# ---> 72         # key inserted. Let's check if we're balanced
#      73         self.update_heights(False)
#      74         self.update_balances(False)
#
# ~/Documents/UNB/EDA2/trabsons/Lista5_GustavoVeloso_LucasGanda/avl_tree.py in inner_find(root)
#      64             return self.node
#      65         elif self.node.key > key:
# ---> 66             return find_node(self.node.left)
#      67         elif self.node.key < key:
#      68             return find_node(self.node.right)
#
# ~/Documents/UNB/EDA2/trabsons/Lista5_GustavoVeloso_LucasGanda/avl_tree.py in inner_find(root)
#      63         if self.node.key == key:
#      64             return self.node
# ---> 65         elif self.node.key > key:
#      66             return find_node(self.node.left)
#      67         elif self.node.key < key:
#
# AttributeError: 'AVLTree' object has no attribute 'key'
